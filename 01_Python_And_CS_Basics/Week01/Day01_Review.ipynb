# %% [markdown]
# # Day 01 복습 정리
#
# ## 1. 오늘 배운 핵심 키워드
# - 변수, 자료형, print 함수
#
# ## 2. 실습 중 자주 틀린 포인트
# - 문자열/숫자 따옴표 실수
# - True/False 대소문자 실수
#
# ## 3. 퀴즈 오답 정리
#
# ### 문제 1
# - 내가 고른 답: d
# - 실제 정답: d
# - 오답 이유:
# - 개념 정리:
#
# ### 문제 2
# - 내가 고른 답: c
# - 실제 정답: c
# - 오답 이유:
# - 개념 정리:
#
# ### 문제 3
# - 내가 고른 답: b
# - 실제 정답: b
# - 오답 이유:
# - 개념 정리:
#
# ## 4. 오늘의 학습 회고
# - 이해도: 전체적으로 잘 이해할 수 있었고 막힘 없이 진행되었음
# - 학습 시간: 2시간
# - 집중도 평가 (1~5): 4
# - 컨디션 메모: 첫 학습으로 매우 집중하여 학습함
#
# ## 5. 아직 애매하거나 이해되지 않은 개념
# - 정수형과 실수형의 정확한 차이를 모르겠음
#
# ## 6. 실전 응용 또는 포트폴리오 확장 아이디어
# - 간단한 자기소개 프로그램
#   - 이름, 나이, 취미, 목표 등을 변수에 저장하고 print()로 출력
#
# ## 7. 내일을 위한 준비 및 예습
# - [x] 예습 영상: [생활코딩 Python 연산자 강의](https://www.youtube.com/watch?v=dQw4w9WgXcQ) (2:40~6:20)
#
#   <details>
#   <summary><strong></strong></summary>
#
#   > Never gonna give you up
#   > Never gonna let you down
#   > Never gonna run around and desert you
#
#   > 오늘은 포기하지 말자는 의미로 이 노래를 기억합니다.
#   > Day01부터 Day222까지 중요한 것은 꺾이지 않는 마음.
#
#
#   </details>
#
#
# - [x] 교재 읽기: 점프 투 파이썬 p.41~50
# - [x] Jupyter/Colab에서 print 실습 셀 준비
